# %% [markdown]
# <a href="https://colab.research.google.com/github/RM-RAMASAMY/CMPE-255-Assignments/blob/main/Image%2BText%2BTabular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: get user input as string

input_string = input("Enter a string: ")
print("You entered:", input_string)

# %% [markdown]
# # AutoMM for Image + Text + Tabular - Quick Start
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/autogluon/autogluon/blob/stable/docs/tutorials/multimodal/multimodal_prediction/beginner_multimodal.ipynb)
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/autogluon/autogluon/blob/stable/docs/tutorials/multimodal/multimodal_prediction/beginner_multimodal.ipynb)
#
#
#
# AutoMM is a deep learning "model zoo" of model zoos. It can automatically build deep learning models that are suitable for multimodal datasets. You will only need to convert the data into the multimodal dataframe format
# and AutoMM can predict the values of one column conditioned on the features from the other columns including images, text, and tabular data.

# %%
# !pip install autogluon.multimodal
# Out:
# Requirement already satisfied: autogluon.multimodal in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: numpy<2.1.4,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.26.4)
# Requirement already satisfied: scipy<1.16,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.13.1)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.2.2)
# Requirement already satisfied: scikit-learn<1.5.3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.5.2)
# Requirement already satisfied: Pillow<12,>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (11.0.0)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (4.67.1)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.35.83)
# Requirement already satisfied: torch<2.6,>=2.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.5.1+cu121)
# Requirement already satisfied: lightning<2.6,>=2.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.4.0)
# Requirement already satisfied: transformers<5,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal) (4.47.0)
# Requirement already satisfied: accelerate<1.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.34.2)
# Requirement already satisfied: requests<3,>=2.30 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.32.3)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.4.3)
# Requirement already satisfied: timm<1.0.7,>=0.9.5 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.0.3)
# Requirement already satisfied: torchvision<0.21.0,>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.20.1+cu121)
# Requirement already satisfied: scikit-image<0.25.0,>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.24.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.2.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.2.3)
# Requirement already satisfied: autogluon.core==1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.core[raytune]==1.2->autogluon.multimodal) (1.2)
# Requirement already satisfied: autogluon.features==1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.2)
# Requirement already satisfied: autogluon.common==1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.2)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.1.11)
# Requirement already satisfied: nltk<3.9,>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (3.1.4)
# Requirement already satisfied: tensorboard<3,>=2.9 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (2.17.1)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.multimodal) (1.17.0)
# Requirement already satisfied: psutil<7.0.0,>=5.7.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.2->autogluon.multimodal) (5.9.5)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (3.4.2)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (3.8.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core[raytune]==1.2->autogluon.multimodal) (17.0.0)
# Requirement already satisfied: ray<2.40,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.39.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from autogluon.core[raytune]==1.2->autogluon.multimodal) (0.2.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal) (0.4.5)
# Requirement already satisfied: botocore<1.36.0,>=1.35.83 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.multimodal) (1.35.83)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.multimodal) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.multimodal) (0.10.4)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (3.2.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal) (0.22.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning<2.6,>=2.2->autogluon.multimodal) (0.11.9)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning<2.6,>=2.2->autogluon.multimodal) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning<2.6,>=2.2->autogluon.multimodal) (2.4.0)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (5.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal) (2024.11.6)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal) (4.9.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.1.11)
# Requirement already satisfied: opendatalab in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.0.10)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (24.1.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.multimodal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.multimodal) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.multimodal) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.30->autogluon.multimodal) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.30->autogluon.multimodal) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.30->autogluon.multimodal) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.30->autogluon.multimodal) (2024.12.14)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.5.3,>=1.4.0->autogluon.multimodal) (3.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<2.6,>=2.2->autogluon.multimodal) (3.16.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch<2.6,>=2.2->autogluon.multimodal) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch<2.6,>=2.2->autogluon.multimodal) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.38.0->transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal) (0.21.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal) (0.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (3.11.10)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (4.12.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==1.2->autogluon.multimodal) (3.1.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[raytune]==1.2->autogluon.multimodal) (3.2.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray<2.40,>=2.10.0->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.5.0)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.6.2.2)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.7.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.4.0)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.10.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.21.1)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (7.0.5)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (20.28.0)
# Requirement already satisfied: memray in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.15.0)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.10/dist-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (4.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (3.21.0)
# Requirement already satisfied: openxlab in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.0.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (2.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.27.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (4.3.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (2.6)
# Requirement already satisfied: textual>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.0.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.19.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (1.7.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.27.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (4.9)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.4.2)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "raytune"->autogluon.core[raytune]==1.2->autogluon.multimodal) (0.6.1)

# %%
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')
np.random.seed(123)

# %% [markdown]
# ## Dataset
#
# For demonstration, we use a simplified and subsampled version of [PetFinder dataset](https://www.kaggle.com/c/petfinder-adoption-prediction). The task is to predict the animals' adoption rates based on their adoption profile information. In this simplified version, the adoption speed is grouped into two categories: 0 (slow) and 1 (fast).
#
# To get started, let's download and prepare the dataset.

# %%
download_dir = './ag_automm_tutorial'
zip_file = 'https://automl-mm-bench.s3.amazonaws.com/petfinder_for_tutorial.zip'
from autogluon.core.utils.loaders import load_zip
load_zip.unzip(zip_file, unzip_dir=download_dir)
# Out:
# Unzipping ./ag_automm_tutorial/file.zip to ./ag_automm_tutorial

# %% [markdown]
# Next, we will load the CSV files.

# %%
import pandas as pd
dataset_path = download_dir + '/petfinder_for_tutorial'
train_data = pd.read_csv(f'{dataset_path}/train.csv', index_col=0)
test_data = pd.read_csv(f'{dataset_path}/test.csv', index_col=0)
label_col = 'AdoptionSpeed'

# %% [markdown]
# We need to expand the image paths to load them in training.

# %%
image_col = 'Images'
train_data[image_col] = train_data[image_col].apply(lambda ele: ele.split(';')[0]) # Use the first image for a quick tutorial
test_data[image_col] = test_data[image_col].apply(lambda ele: ele.split(';')[0])


def path_expander(path, base_folder):
    path_l = path.split(';')
    return ';'.join([os.path.abspath(os.path.join(base_folder, path)) for path in path_l])

train_data[image_col] = train_data[image_col].apply(lambda ele: path_expander(ele, base_folder=dataset_path))
test_data[image_col] = test_data[image_col].apply(lambda ele: path_expander(ele, base_folder=dataset_path))

train_data[image_col].iloc[0]
# Out:
# '/content/ag_automm_tutorial/petfinder_for_tutorial/images/7d7a39d71-1.jpg'

# %% [markdown]
# Each animal's adoption profile includes pictures, a text description, and various tabular features such as age, breed, name, color, and more. Let's look at an example row of data and display the text description and a picture.

# %%
example_row = train_data.iloc[0]

example_row
# Out:
# Type                                                             2
# Name                                                 Yumi Hamasaki
# Age                                                              4
# Breed1                                                         292
# Breed2                                                         265
# Gender                                                           2
# Color1                                                           1
# Color2                                                           5
# Color3                                                           7
# MaturitySize                                                     2
# FurLength                                                        2
# Vaccinated                                                       1
# Dewormed                                                         3
# Sterilized                                                       2
# Health                                                           1
# Quantity                                                         1
# Fee                                                              0
# State                                                        41326
# RescuerID                         bcc4e1b9557a8b3aaf545ea8e6e86991
# VideoAmt                                                         0
# Description      I rescued Yumi Hamasaki at a food stall far aw...
# PetID                                                    7d7a39d71
# PhotoAmt                                                       3.0
# AdoptionSpeed                                                    0
# Images           /content/ag_automm_tutorial/petfinder_for_tuto...
# Name: 0, dtype: object

# %%
example_row['Description']
# Out:
# "I rescued Yumi Hamasaki at a food stall far away in Kelantan. At that time i was on my way back to KL, she was suffer from stomach problem and looking very2 sick.. I send her to vet & get the treatment + vaccinated and right now she's very2 healthy.. About yumi : - love to sleep with ppl - she will keep on meowing if she's hugry - very2 active, always seeking for people to accompany her playing - well trained (poo+pee in her own potty) - easy to bathing - I only feed her with these brands : IAMS, Kittenbites, Pro-formance Reason why i need someone to adopt Yumi: I just married and need to move to a new house where no pets are allowed :( As Yumi is very2 special to me, i will only give her to ppl that i think could take care of her just like i did (especially on her foods things).."

# %%
example_image = example_row[image_col]

from IPython.display import Image, display
pil_img = Image(filename=example_image)
display(pil_img)

# %% [markdown]
# ## Training
# Now let's fit the predictor with the training data. Here we set a tight time budget for a quick demo.

# %%
from autogluon.multimodal import MultiModalPredictor
predictor = MultiModalPredictor(label=label_col)
predictor.fit(
    train_data=train_data,
    time_limit=120, # seconds
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241218_174111"
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Pytorch Version:    2.5.1+cu121
# CUDA Version:       CUDA is not available
# Memory Avail:       10.48 GB / 12.67 GB (82.7%)
# Disk Space Avail:   74.41 GB / 107.72 GB (69.1%)
# ===================================================
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
#
# AutoMM starts to create your model. ✨✨✨
#
# To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/AutogluonModels/ag-20241218_174111
#     ```
#
# INFO: Seed set to 0
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/395M [00:00<?, ?B/s]
# GPU Count: 0
# GPU Count to be Used: 0
#
# INFO: GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:
#   | Name              | Type                | Params | Mode
# ------------------------------------------------------------------
# 0 | model             | MultimodalFusionMLP | 207 M  | train
# 1 | validation_metric | BinaryAUROC         | 0      | train
# 2 | loss_func         | CrossEntropyLoss    | 0      | train
# ------------------------------------------------------------------
# 207 M     Trainable params
# 0         Non-trainable params
# 207 M     Total params
# 828.307   Total estimated model params size (MB)
# 946       Modules in train mode
# 225       Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO: Time limit reached. Elapsed time is 0:02:02. Signaling Trainer to stop.
# Validation: |          | 0/? [00:00<?, ?it/s]
# AutoMM has created your model. 🎉🎉🎉
#
# To load the model, use the code below:
#     ```python
#     from autogluon.multimodal import MultiModalPredictor
#     predictor = MultiModalPredictor.load("/content/AutogluonModels/ag-20241218_174111")
#     ```
#
# If you are not satisfied with the model, try to increase the training time,
# adjust the hyperparameters (https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/customization.html),
# or post issues on GitHub (https://github.com/autogluon/autogluon/issues).

# %% [markdown]
# Under the hood, AutoMM automatically infers the problem type (classification or regression), detects the data modalities, selects the related models from the multimodal model pools, and trains the selected models. If multiple backbones are available, AutoMM appends a late-fusion model (MLP or transformer) on top of them.
#
#
# ## Evaluation
# Then we can evaluate the predictor on the test data.

# %%
scores = predictor.evaluate(test_data, metrics=["roc_auc"])
scores
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# {'roc_auc': 0.6048}

# %% [markdown]
# ## Prediction
# Given a multimodal dataframe without the label column, we can predict the labels.

# %%
predictions = predictor.predict(test_data.drop(columns=label_col))
predictions[:5]
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# 8     0
# 70    0
# 82    1
# 28    1
# 63    1
# Name: AdoptionSpeed, dtype: int64

# %% [markdown]
# For classification tasks, we can get the probabilities of all classes.

# %%
probas = predictor.predict_proba(test_data.drop(columns=label_col))
probas[:5]
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
#            0         1
# 8   0.628740  0.371260
# 70  0.731549  0.268451
# 82  0.115926  0.884074
# 28  0.315731  0.684269
# 63  0.090961  0.909039

# %% [markdown]
# Note that calling `.predict_proba()` on one regression task will throw an exception.
#
#
# ## Extract Embeddings
#
# Extracting embeddings can also be useful in many cases, where we want to convert each sample (per row in the dataframe) into an embedding vector.

# %%
embeddings = predictor.extract_embedding(test_data.drop(columns=label_col))
embeddings.shape
# Out:
# Predicting: |          | 0/? [00:00<?, ?it/s]
# (100, 128)

# %% [markdown]
# ## Save and Load
# It is also convenient to save a predictor and re-load it.
#
# ```{warning}
#
# `MultiModalPredictor.load()` uses `pickle` module implicitly, which is known to be insecure. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling. Never load data that could have come from an untrusted source, or that could have been tampered with. **Only load data you trust.**
#
# ```

# %%
import uuid

model_path = f"./tmp/{uuid.uuid4().hex}-saved_model"
predictor.save(model_path)
loaded_predictor = MultiModalPredictor.load(model_path)
scores2 = loaded_predictor.evaluate(test_data, metrics=["roc_auc"])
scores2
# Out:
# Load pretrained checkpoint: /content/tmp/b54746199dbf4ced9e10ecd4c072bee6-saved_model/model.ckpt
# Predicting: |          | 0/? [00:00<?, ?it/s]
# {'roc_auc': 0.6048}

# %% [markdown]
# ## Other Examples
#
# You may go to [AutoMM Examples](https://github.com/autogluon/autogluon/tree/master/examples/automm) to explore other examples about AutoMM.
#
# ## Customization
# To learn how to customize AutoMM, please refer to [Customize AutoMM](../advanced_topics/customization.ipynb).
